# %% [markdown]
# The content of the following cell install the pywars client into this notebook. It must be executed once during the lifetime of a notebooks execution.  If you save and reopen the notebook you will need to execute again, but otherwise you only need to run it once.

# %%
#Import and/or install the pywars client
# !git clone --branch version5 https://github.com/markbaggett/pyWars
# !pip install ./pyWars

#Mount the google drive in colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Cloning into 'pyWars'...
# remote: Enumerating objects: 193, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 193 (delta 5), reused 11 (delta 3), pack-reused 177 (from 1)
# Receiving objects: 100% (193/193), 38.43 KiB | 1.24 MiB/s, done.
# Resolving deltas: 100% (106/106), done.
# Processing ./pyWars
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from pywars==5.0.4) (2.32.4)
# Requirement already satisfied: rich>=9.1.0 in /usr/local/lib/python3.12/dist-packages (from pywars==5.0.4) (13.9.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20.0->pywars==5.0.4) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20.0->pywars==5.0.4) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20.0->pywars==5.0.4) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20.0->pywars==5.0.4) (2026.1.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=9.1.0->pywars==5.0.4) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=9.1.0->pywars==5.0.4) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=9.1.0->pywars==5.0.4) (0.1.2)
# Building wheels for collected packages: pywars
#   Building wheel for pywars (pyproject.toml) ... done
#   Created wheel for pywars: filename=pywars-5.0.4-py3-none-any.whl size=8830 sha256=37a63f0aa6b2cd80b2770962a299c2ebf7b72b87d9fa1609741c82d95a8f1721
#   Stored in directory: /tmp/pip-ephem-wheel-cache-b6o5djyz/wheels/76/37/a7/9cfc81a1d79f0ceb96262c579268e440f053bf7c6cd9142399
# Successfully built pywars
# Installing collected packages: pywars
# Successfully installed pywars-5.0.4
# Mounted at /content/drive

# %% [markdown]
# This next command must be run once to configure your pyWars server and to login.  Be sure to put your username and password in the .login() function.  Before running this you must change the contents of the three variables below to reflect your account information provided by SANS.

# %%
#Set the following three variables and execute this cell
HOSTNAME = 'python.sans.edu'
USERNAME = 'pywars_login_9542'
PASSWORD = 'Phq1wm9DVWj667fSyjGs'

#This will create your pywars client object and store in the variable d
import pywars
d = pywars.Client(f"https://{HOSTNAME}:10000")
d.file_location="/content/drive/MyDrive"
d.login(USERNAME,PASSWORD)
# Out:
# 'Login Success'

# %% [markdown]
# Now you can use pywars client stored in variables `d` to interact with the server. For example, you can print `d.names` to see all of the available labs.

# %%
print(d.names)
# Out:
# ['intro1.0', 'intro1.1', 'intro1.2', 'intro1.3', 'intro1.4', 'intro1.5', 'intro1.6', 'intro1.7', 'intro1.8', 'intro1.9', 'intro1.10', 'intro1.11', 'quiz1.00', 'quiz1.01', 'quiz1.02', 'quiz1.03', 'quiz1.04', 'quiz1.05', 'quiz1.06', 'quiz1.07', 'quiz1.08', 'quiz1.09', 'math-addition', 'math-division', 'math-longdivision', 'math-multiply', 'math-remainder', 'math-floor', 'math-absolute-values', 'math-exponent', 'math-float', 'math-bitshift', 'math-operation-order', 'math-binary-bit-set', 'math-binary-bit-clear', 'math-two-floats', 'math-int2chr', 'math-chr2int', 'math-oct2int', 'math-int2bin', 'math-int2bin-two', 'math-bin2int', 'math-int2hex', 'math-hex2int', 'quiz2.00', 'quiz2.01', 'quiz2.02', 'quiz2.03', 'quiz2.04', 'quiz2.05', 'quiz2.06', 'quiz2.07', 'quiz2.08', 'quiz2.09', 'str-caps', 'str-substring', 'str-byte-storage', 'str-exes-n-ohs', 'str-bytes2str', 'str-str2bytes', 'str-slice1', 'str-slice2', 'str-slice3', 'str-slice4', 'str-replace', 'str-length', 'str-count', 'str-raw', 'str-64-decode', 'str-64-encode', 'str-rot13', 'problem-rounded-float', 'problem-wierd-binary', 'problem-byte-addition', 'problem-byte-addition2', 'problem-next-char', 'problem-next-chars', 'problem-palindrome', 'problem-repeated-string', 'problem-float-back', 'problem-temperature', 'problem-new-word', 'problem-swap-letters', 'problem-md5-hash', 'quiz3.00', 'quiz3.01', 'quiz3.02', 'quiz3.03', 'quiz3.04', 'quiz3.05', 'quiz3.06', 'quiz3.07', 'quiz3.08', 'quiz3.09', 'function-add', 'function-num-spaces', 'function-subtract-letters', 'function-adlib', 'function-undomino', 'function-type-check', 'function-talking-about', 'function-calculator', 'list-slice', 'list-range', 'list-length', 'list-split-n-slice', 'list-append', 'list-addition', 'list-addition2', 'list-join', 'list-wierd-range', 'list-un-hexdump', 'list-combining', 'list-sorting-numbers', 'list-insert', 'list-odds', 'list-inc-each', 'td-tuple-item', 'td-tuple-update', 'td-tuple-subitem', 'td-dict-keys', 'td-dict-values', 'td-dict-items', 'file-io1', 'file-io2', 'file-io3', 'file-io4', 'assignment1', 'assignment2', 'assignment3', 'extra-credit-crypto-cracker-practice', 'extra-credit-crypto-cracker']

# %% [markdown]
# You can look at the questions by calling d.question() and passing it either a question number or the question name.  The table that is displayed gives you more information about the question. Below the table is the question itself.

# %%
d.question("intro1.0")
# Out:
# ┏━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ # ┃ Question ┃ Points ┃ Timeout   ┃ Attempts  ┃ Prerequisites ┃
# ┡━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 0 │ intro1.0 │ 1      │ Not Timed │ UNLIMITED │ NONE          │
# └───┴──────────┴────────┴───────────┴───────────┴───────────────┘
# TEXT:
# This is an example of a quiz style multiple choice question. Enter "print(d.data('intro1.0'))" to see your choices.
# Then enter "d.answer( 9999 )" where 9999 is integer next to word 'red'. These instructions assume you are using the
# variable "d". If you use a different variable adjust the command accordingly.
#
# Enter "print(d.data('intro1.0'))" to view the choices. Submit the integer next to the correct choice. For example:
# 'd.answer(1)'

# %% [markdown]
# Many of the questions will require that manipulate some data in some way. So it is often necessary for you to also look at the data before you understand what you have to accomplish.  When calling the d.data() you can also provide either a lab name of number.

# %%
print(d.data("intro1.0"))
# Out:
# 0) yellow
# 1) red
# 2) yellow
# 3) yellow

# %% [markdown]
# There are two different ways you submit answers to the server. Sometimes you are asked to upload some code using `d.solution()` and other times you will submit your answer using `d.answer()`. When calling `d.answer()` you will pass a value that stores a manipulated version of the data provided by `d.data()`.

# %%
d.answer( "1" )
# Out:
# 'Correct!'

# %% [markdown]
# After submitting that answer you should see the response "Correct!". Now you can check your score by running `d.score()`. The table that comes back will show you the numbers of the questions you have already completed.

# %%
d.score()
# Out:
#                          Scoreboard
# ┏━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ Rank ┃ Name        ┃ Score ┃ Last Scored     ┃ Completed ┃
# ┡━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━┩
# │ 001  │ Coder78c64b │ 001   │ Feb,09 21:02:54 │ 0         │
# └──────┴─────────────┴───────┴─────────────────┴───────────┘

# %% [markdown]
# If you see that you have not completed a specific challenge and want to complete it you can either submit that question number to `d.question()` or you can lookup the question names using `d.num2name()`.  For example, here is how you can look up the name of question number 2.

# %%
d.num2name(0)
# Out:
# 'intro1.0'

# %% [markdown]
# Now try creating a new cell below and changing the strings `intro1.0` to the string `intro1.1`. After changing the string run the cell by clicking play or pressing `CTRL+ENTER`.  Using this process query the question named `intro1.1`, query its data, and submit the correct answer.  Repeat this process for the the labs `intro1.1` through `intro1.9`.
#
# After completing each of those you have completed this lab. Please add your new cells below and work through all of the intro challenges as demonstrated in the lecture video. When you are finished save your work to your google drive.

# %%
d.score()
# Out:
#                          Scoreboard
# ┏━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ Rank ┃ Name        ┃ Score ┃ Last Scored     ┃ Completed ┃
# ┡━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━┩
# │ 001  │ Coder78c64b │ 001   │ Feb,09 21:02:54 │ 0         │
# └──────┴─────────────┴───────┴─────────────────┴───────────┘

# %%
d.question("intro1.1")
# Out:
# ┏━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ # ┃ Question ┃ Points ┃ Timeout   ┃ Attempts ┃ Prerequisites ┃
# ┡━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 1 │ intro1.1 │ 1      │ Not Timed │ 1        │ NONE          │
# └───┴──────────┴────────┴───────────┴──────────┴───────────────┘
# TEXT:
# You can only miss a quiz question once. Observe what happens when you submit the incorrect answer. Then try to
# submit another answer. Don't worry about the correct answer. This question is an unwinnable scenario. It is better
# to know what an incorrect question looks like now, instead of when it counts. Remember to
# "print(d.data('intro1.1'))" to see the choices.
#
# Enter "print(d.data('intro1.1'))" to view the choices. Submit the integer next to the correct choice. For example:
# 'd.answer(1)'

# %%
d.data(1)
# Out:
# '0) i am wrong\n1) i am wrong\n2) i am wrong\n3) i am wrong'

# %%
print(d.data(1))
# Out:
# 0) i am wrong
# 1) i am wrong
# 2) i am wrong
# 3) i am wrong

# %%
d.answer(1)
# Out:
# 'You can no longer attempt to answer this question.'

# %%
d.answer(2)
# Out:
# 'You can no longer attempt to answer this question.'

# %%
d.question("intro1.2")
# Out:
# ┏━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ # ┃ Question ┃ Points ┃ Timeout   ┃ Attempts ┃ Prerequisites ┃
# ┡━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 2 │ intro1.2 │ 1      │ Not Timed │ 1        │ NONE          │
# └───┴──────────┴────────┴───────────┴──────────┴───────────────┘
# TEXT:
# Which of the choices in .data() starts with the letter M?
#
# Enter "print(d.data('intro1.2'))" to view the choices. Submit the integer next to the correct choice. For example:
# 'd.answer(1)'

# %%
print(d.data(2))
# Out:
# 0) It isnt me
# 1) Choosing me is a bad idea
# 2) ME!
# 3) Not me

# %%
d.answer(2)
# Out:
# 'Correct!Already Scored'

# %%
d.question("intro1.3")
# Out:
# ┏━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ # ┃ Question ┃ Points ┃ Timeout   ┃ Attempts ┃ Prerequisites ┃
# ┡━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 3 │ intro1.3 │ 2      │ Not Timed │ 1        │ NONE          │
# └───┴──────────┴────────┴───────────┴──────────┴───────────────┘
# TEXT:
# Notice that this one is worth more than one point! The point values change. The question is, how many points is
# this question worth?
#
# Enter "print(d.data('intro1.3'))" to view the choices. Submit the integer next to the correct choice. For example:
# 'd.answer(1)'

# %%
print(d.data(3))
# Out:
# 0) less than zero
# 1) ten
# 2) zero
# 3) two

# %%
d.answer(3)
# Out:
# 'Correct!Already Scored'

# %%
d.question("intro1.4")
# Out:
# ┏━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ # ┃ Question ┃ Points ┃ Timeout   ┃ Attempts ┃ Prerequisites ┃
# ┡━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 4 │ intro1.4 │ 1      │ Not Timed │ 1        │ NONE          │
# └───┴──────────┴────────┴───────────┴──────────┴───────────────┘
# TEXT:
# You will also notice a question number next to the question name in the table. You can use either the name or the
# number to ask for the data. Try to 'print(d.data(4))'. Then answer the question, which of those is 'python'?
#
# Enter "print(d.data('intro1.4'))" to view the choices. Submit the integer next to the correct choice. For example:
# 'd.answer(1)'

# %%
print(d.data(4))
# Out:
# 0) c++
# 1) powershell
# 2) python
# 3) go

# %%
d.answer(2)
# Out:
# 'Correct!Already Scored'

# %%
d.question("intro1.5")
# Out:
# ┏━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ # ┃ Question ┃ Points ┃ Timeout ┃ Attempts  ┃ Prerequisites ┃
# ┡━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 5 │ intro1.5 │ 1      │ 3       │ UNLIMITED │ NONE          │
# └───┴──────────┴────────┴─────────┴───────────┴───────────────┘
# TEXT:
# For the quiz questions it is formatted properly on your screen when you print() then data. However, many of your
# questions require you do more than just print the data. They require that you read the .data(), change the value it
# returns in some way then submit the changed version as the answer. These types of questions has a timeout. The
# timeout is typically 3 seconds but it is displayed in the table. When you call .data() the server starts a count
# down clock. You must submit your answer by calling .answer() before the timeout expires to get the points. To
# complete this question, read the string returned when you call .data('intro1.5') and submit it to .answer() in less
# than three seconds.

# %%
d.data("intro1.5")
# Out:
# 'SUBMIT-ME'

# %%
d.answer("SUBMIT-ME")
# Out:
# 'timed out'

# %%
d.data("intro1.5")
d.answer("SUBMIT-ME")
# Out:
# 'Correct!Already Scored'

# %%
d.question("intro1.6")
# Out:
# ┏━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ # ┃ Question ┃ Points ┃ Timeout ┃ Attempts  ┃ Prerequisites ┃
# ┡━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 6 │ intro1.6 │ 1      │ 3       │ UNLIMITED │ NONE          │
# └───┴──────────┴────────┴─────────┴───────────┴───────────────┘
# TEXT:
# For the last one the data didn't change. So you could have answered it by typing
# 'variable.data("intro1.5");variable.answer("SUBMIT-ME")'. But that won't work for this one. The data on most
# challenges changes every time you ask for it. That means you have to read it, process it, and submit the answer
# before the timeout. Call .data('intro1.6') a few times. Notice that the data is different every time. Then to
# complete this question, read the data and submit it as the answer in less than three seconds.

# %%
d.data("intro1.6")
# Out:
# 436852

# %%
x = d.data("intro1.6")
d.answer(x)
# Out:
# 'Correct!Already Scored'

# %%
d.answer(d.data("intro1.6"))
# Out:
# 'Correct!Already Scored'

# %%
d.question("intro1.7")
# Out:
# ┏━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ # ┃ Question ┃ Points ┃ Timeout ┃ Attempts  ┃ Prerequisites ┃
# ┡━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 7 │ intro1.7 │ 1      │ 3       │ UNLIMITED │ NONE          │
# └───┴──────────┴────────┴─────────┴───────────┴───────────────┘
# TEXT:
# Intro: You can get a full list of all of the challenge names by putting .names after your pyWars variable. Example
# 'variable.names'. Sometimes .data() will return multiple values. To capture the values into individual variables
# just put multiple variable names on the left side of the equal sign. For example, this challenge returns 3
# different values. Capture them by running 'var1,var2,var3 = d.data("intro1.7")'.  Then submit only the second value
# as the answer.

# %%
var1,var2,var3 = d.data("intro1.7")

# %%
var1,var2,var3 = d.data("intro1.7")
d.answer(var2)
# Out:
# 'Correct!Already Scored'

# %%
d.question("intro1.8")
# Out:
# ┏━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ # ┃ Question ┃ Points ┃ Timeout ┃ Attempts  ┃ Prerequisites ┃
# ┡━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 8 │ intro1.8 │ 1      │ 3       │ UNLIMITED │ NONE          │
# └───┴──────────┴────────┴─────────┴───────────┴───────────────┘
# TEXT:
# You can enter 'd.score()' to see your progress. In a multi-player game you can call 'd.score(1)' to see everyones
# progress. You can also call 'd.displayname("My New Name") to change how you appear on the scoreboard. To score
# another point read the .data() subtract 10 from it and submit the answer.

# %%
d.score()
# Out:
#                          Scoreboard
# ┏━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ Rank ┃ Name        ┃ Score ┃ Last Scored     ┃ Completed ┃
# ┡━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━┩
# │ 001  │ Coder78c64b │ 008   │ Feb,09 22:21:16 │ 0,2-7     │
# └──────┴─────────────┴───────┴─────────────────┴───────────┘

# %%
d.displayname("ChirpOps")
# Out:
# 'Failed. In use.'

# %%
d.score()
# Out:
#                        Scoreboard
# ┏━━━━━━┳━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ Rank ┃ Name     ┃ Score ┃ Last Scored     ┃ Completed ┃
# ┡━━━━━━╇━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━┩
# │ 001  │ ChirpOps │ 008   │ Feb,09 22:21:16 │ 0,2-7     │
# └──────┴──────────┴───────┴─────────────────┴───────────┘

# %%
d.question("intro1.9")
# Out:
# Folder download skipped because the folder already exists. Call .attachment('labname',overwrite=True) to redownload
# and overwrite the exiting folder.
# ┏━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ # ┃ Question ┃ Points ┃ Timeout   ┃ Attempts  ┃ Prerequisites ┃
# ┡━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 9 │ intro1.9 │ 1      │ Not Timed │ UNLIMITED │ NONE          │
# └───┴──────────┴────────┴───────────┴───────────┴───────────────┘
# TEXT:
# Some challenges drop a folder in your /content/drive/MyDrive folder with things you will need. This challenge just
# created a folder named "intro1.9". Notice above that the "TIMEOUT" field says that this challenge is "NOT TIMED".
# Inspect the one file that is in that folder to discover the answer to this question.

# %%
d.data(8)
# Out:
# 916470

# %%
x = d.data(8)
d.answer(x-10)
# Out:
# 'Correct!Already Scored'

# %%
d.question("intro1.9")
# Out:
# Folder download skipped because the folder already exists. Call .attachment('labname',overwrite=True) to redownload
# and overwrite the exiting folder.
# ┏━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ # ┃ Question ┃ Points ┃ Timeout   ┃ Attempts  ┃ Prerequisites ┃
# ┡━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 9 │ intro1.9 │ 1      │ Not Timed │ UNLIMITED │ NONE          │
# └───┴──────────┴────────┴───────────┴───────────┴───────────────┘
# TEXT:
# Some challenges drop a folder in your /content/drive/MyDrive folder with things you will need. This challenge just
# created a folder named "intro1.9". Notice above that the "TIMEOUT" field says that this challenge is "NOT TIMED".
# Inspect the one file that is in that folder to discover the answer to this question.

# %%
d.data(9)
d.answer('i-read-it')
# Out:
# 'Correct!Already Scored'

# %%
d.question("intro1.10")
# Out:
# Folder download skipped because the folder already exists. Call .attachment('labname',overwrite=True) to redownload
# and overwrite the exiting folder.
# ┏━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ #  ┃ Question  ┃ Points ┃ Timeout   ┃ Attempts  ┃ Prerequisites ┃
# ┡━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 10 │ intro1.10 │ 1      │ Not Timed │ UNLIMITED │ NONE          │
# └────┴───────────┴────────┴───────────┴───────────┴───────────────┘
# TEXT:
# This challenge has no timeout so you can take as long as you need to solve it. I just put a python program in the a
# new folder called "intro1.10" in your /content/drive/MyDrive folder. When you run the program named "runme.py" in
# that folder it will print a message. Execute the program to receive further instructions.

# %%
# !python3 /content/drive/MyDrive/intro1.10/runme.py
# Out:
# To complete this question enter "d.answer('I-RAN-IT!')".

# %%
d.answer('I-RAN-IT')
# Out:
# 'You must query the data first.'

# %%
d.data(10)
d.answer('I-RAN-IT!')
# Out:
# 'Correct!Already Scored'

# %%
d.question(11)
# Out:
# Folder download skipped because the folder already exists. Call .attachment('labname',overwrite=True) to redownload
# and overwrite the exiting folder.
# ┏━━━━┳━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ #  ┃ Question  ┃ Points ┃ Timeout ┃ Attempts  ┃ Prerequisites ┃
# ┡━━━━╇━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 11 │ intro1.11 │ 1      │ 15      │ UNLIMITED │ NONE          │
# └────┴───────────┴────────┴─────────┴───────────┴───────────────┘
# TEXT:
# Some challenges require that you modify the files that are placed on folders in your /content/drive/MyDrive folder
# and then resubmit them to the server. This challenge requires that you modify the program named "changeme.py" by
# follow the instructions in that file. After you have made the required changes you submit the updated file by
# entering "d.solution('/content/drive/MyDrive/intro1.11/changeme.py')".

# %%
d.solution("/content/drive/MyDrive/intro1.11/changeme.py")
# Out:
# Correct!
# test_file_changed (test.TestSolution) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK
